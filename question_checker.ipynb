# %%
import os
from collections import defaultdict
import pandas as pd

# %%
# 设置文件夹路径
question_dir = 'D:\\VQA\\validation\\Questions'
answers_dir = 'D:\\VQA\\validation\\Answers'

# 调整Pandas显示设置
pd.set_option('display.max_rows', None)  # 显示所有行
pd.set_option('display.max_columns', None)  # 显示所有列
pd.set_option('display.max_colwidth', None)  # 显示完整列内容
pd.set_option('display.width', 1000)  # 设置显示宽度

# %%
def count_questions(directory):
    question_counts = defaultdict(int)
    error_files = []  # 用来收集出现解码错误的文件列表
    
    # 检查目录是否存在
    if not os.path.exists(directory):
        print(f"Directory does not exist: {directory}")
        return pd.DataFrame(), pd.DataFrame()
    
    # 遍历指定目录下的所有文件
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)
        # 确保是文件而非目录
        if os.path.isfile(file_path):
            try:
                with open(file_path, 'r', encoding='utf-8') as file:
                    content = file.read().strip()  # 读取整个文件内容作为一个问题
                    question_counts[content] += 1
            except UnicodeDecodeError as e:
                # 添加到错误文件列表
                error_files.append((filename, str(e)))

    # 转换结果为DataFrame
    questions_df = pd.DataFrame(list(question_counts.items()), columns=['Question', 'Count'])
    error_files_df = pd.DataFrame(error_files, columns=['File', 'Error'])

    return questions_df, error_files_df

# 调用函数并打印结果
results_df, errors_df = count_questions(question_dir)

if not results_df.empty:
    print("Question Counts:")
    print(results_df.sort_values(by='Count', ascending=False))
else:
    print("No data found or directory is empty.")

if not errors_df.empty:
    print("\nError Files:")
    print(errors_df)
else:
    print("No decoding errors found.")
# Out:
# Question Counts:
#                                                                                                                                     Question  Count
# 15                                       How many cars are waiting to turn left in the bottom lane, moving from the bottom towards the left?      6
# 44                                   Are there many cars driving on the road right now? Not including the cars waiting at the traffic light.      5
# 20                                                                                     How many pedestrians are crossing the zebra crossing?      5
# 8                                                         In what direction is the car moving on the road? Excluding those that are waiting.      3
# 41                                                                                   Are there many people and motorcycles on the crosswalk?      3
# 14                                                                     How many cars are going straight from left to right in the left lane?      3
# 9                                                                                                   Where are pedestrians crossing the road?      3
# 26                                         How many cars are waiting to go stright in the left-hand lane, moving form the left to the right?      3
# 4                                                                                  Did any car waiting for a red light cross the white line?      3
# 64                                                                            How many cars are traveling straight through the intersection?      3
# 2    How many people, including pedestrians, motorcyclists and cyclists  are waiting to cross the crosswalk from bottom left to bottom right      3
# 53                                                                                   What's in the left turn lane from the top to the right?      2
# 59                                                                                                        Which way are the cars moving now?      2
# 50                                                                                                How many motorcyclists are in the picture?      2
# 45                                        How many cars are waiting to go stright in the right-hand lane, moving form the right to the left?      2
# 24                                                                                          Are there any vehicles turning left on the road?      2
# 43                                                                          How many vehicles are waiting to go straight in the bottom lane?      2
# 61                                                                                 What's in the left turn lane from the bottom to the left?      2
# 39                                                                                          Is there a car going straight across the street?      2
# 37                                                                                   Are there many pedestrians waiting to cross the street?      2
# 1                                                            How many vehicles are waiting to turn left in the lane beyond the intersection?      2
# 30                                                              How many pedestrians are crossing the crosswalk from bottom left to top left      2
# 28                                                                               How many pedestrians cross the crosswalk from left to right      2
# 0                                                          How many vehicles are waiting to go straight in the lane beyond the intersection?      2
# 33                                             How many cars are turning left in the bottom lane, moving from the \tbottom towards the left?      2
# 3                                                                         How many motocyclists is waiting to go stright in the bottom lane.      2
# 12                                                                                     How many cars are driving from the top to the bottom?      2
# 5                                        How many cars are waiting to go stright in the bottom lane, moving from the bottom towards the top?      2
# 6                                                                                            How many cars are going straight left to right?      2
# 16                                                                                        How many cyclists are crossing the zebra crossing?      2
# 25                                                 How many pedestrians are waiting to cross the zebra crossing From bottom left to top left      1
# 54               How many bicyclists and motorcyclists are waiting to cross the sidewalk from left to right in the lower left of the screen?      1
# 49                                                                     How many people on motorcycles are in the left bottom of the picture?      1
# 10                                                                        How many pedestrians are crossing the crosswalk from right to left      1
# 51                                                                                         Are there any vehicles turning right on the road?      1
# 52                                                                                             How many cars are driving from left to right?      1
# 7                      How many cars are waiting to turn left in  the lanes beyond the intersection, moving from the top towards the bottom?      1
# 56  How many cars are waiting to turn left in the left-hand lane, moving from the lane on the left towards the lane beyond the intersection?      1
# 55      How many cars are turning left in the lanes beyond the intersection, moving from the lanes beyond the intersection towards the left?      1
# 47                                                                 How many cars are turning left from the left-hand lane to the upper lane?      1
# 57                                                                                                          What direction is the bus going?      1
# 58                                                                                                           Is there a car making a U-turn?      1
# 60                                            How many motocyclists are waiting to cross the zebra crossing from bottom left to bottom right      1
# 62                                                                         Do you think there are many cars in lands beyond the intersection      1
# 63                                                                                                        What direction is the bus heading?      1
# 48                                                       How many people are waiting to cross the crosswalk from bottom left to bottom right      1
# 11     How many people, including pedestrians, motorcyclists and cyclists  are waiting to cross the crosswalk from bottom left to upper left      1
# 46                                                               How many cars are turning left from the right-hand lane to the bottom lane?      1
# 34                                               How many cars are going straight in the right-hand lane, moving from the right to the left?      1
# 27                                                                                                        How many taxis are in the picture?      1
# 22                                                                                          Where is there a pedestrian crossing the street?      1
# 29                                                                               How many pedestrians cross the crosswalk from right to left      1
# 21                                                                                        How many bicycles are crossing the zebra crossing?      1
# 31                                                                          Did any of the cars have their front wheels over the white line?      1
# 32                                                                                                        How many taxis are there in total?      1
# 19                                                               What direction is the car in the bottom right of the image heading towards?      1
# 35                                  How many vehicles are waiting to turn left in the opposing lane, moving from the top towards the bottom?      1
# 23                                                                                            Where are the motorcyclists crossing the road?      1
# 36                                                                                    Do you think there are many cars in the opposite lane?      1
# 18                                                                     Do you think there are many cars in the lane beyond the intersection?      1
# 38                                                                                            Are there any motorcycles crossing the street?      1
# 17                                                                                   How many vehicles are going straight from right to left      1
# 40                                                                                                               Is there a bus on the road?      1
# 42                                                                      How many people are on the left waiting to go straight to the right?      1
# 13                                                                                     How many cars are driving from the bottom to the top?      1
# 65                                                                                  How many vehicles are making U-turns in the bottom lane?      1
# No decoding errors found.

# %%
#检查问题在哪些文件中出现
def find_files_by_question(directory, target_question):
    # 问题
    target_question = "Where are pedestrians crossing the road?"

    matching_files = []
    # 检查目录是否存在
    if not os.path.exists(directory):
        print(f"Directory does not exist: {directory}")
        return matching_files
    
    # 遍历指定目录下的所有文件
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)
        # 确保是文件而非目录
        if os.path.isfile(file_path):
            try:
                with open(file_path, 'r', encoding='utf-8') as file:
                    content = file.read().strip()  # 读取整个文件内容
                    if content == target_question:  # 比较文件内容与目标问题
                        matching_files.append(filename)
            except UnicodeDecodeError:
                print(f"Could not decode file {file_path} using UTF-8.")

    return matching_files

# 调用函数并打印结果
matching_files = find_files_by_question(question_dir, target_question)
if matching_files:
    print("Matching Files:")
    for file in matching_files:
        print(file)
else:
    print("No files match the provided question.")
# Out:
# Matching Files:
# 148709_sj8fas2e152d20211124air_420_1637216131_1637218737_129_obstacle.txt
# 148709_sj8fas2e152d20211124air_420_1637216131_1637218737_31_obstacle.txt
# 148709_sj8fas2e152d20211124air_420_1637216131_1637218737_94_obstacle.txt

# %%
#替换问题
def find_and_replace_in_files(directory, target_question, new_content):
    # 输入问题和新内容
    target_question = "Where are pedestrians crossing the road"
    new_content = "Where are pedestrians crossing the road?"

    matching_files = []
    modified_files = []

    # 检查目录是否存在
    if not os.path.exists(directory):
        print(f"Directory does not exist: {directory}")
        return matching_files, modified_files

    # 遍历指定目录下的所有文件
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)
        # 确保是文件而非目录
        if os.path.isfile(file_path):
            try:
                with open(file_path, 'r', encoding='utf-8') as file:
                    content = file.read().strip()  # 读取整个文件内容
                    if content == target_question:  # 比较文件内容与目标问题
                        matching_files.append(filename)

                        # 替换文件内容
                        with open(file_path, 'w', encoding='utf-8') as file_to_write:
                            file_to_write.write(new_content)
                            modified_files.append(filename)
            except UnicodeDecodeError:
                print(f"Could not decode file {file_path} using UTF-8.")
            except IOError as e:
                print(f"Error while writing to file {file_path}: {e}")

    return matching_files, modified_files

# 调用函数并打印结果
matching_files, modified_files = find_and_replace_in_files(question_dir, target_question, new_content)
if matching_files:
    print("Matching Files:")
    for file in matching_files:
        print(file)
    print("\nModified Files:")
    for file in modified_files:
        print(file)
else:
    print("No files match the provided question.")
# Out:
# Matching Files:
# 148709_sj8fas2e152d20211124air_420_1637216131_1637218737_31_obstacle.txt
#
# Modified Files:
# 148709_sj8fas2e152d20211124air_420_1637216131_1637218737_31_obstacle.txt
