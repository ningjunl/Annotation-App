# %%
import os
from collections import defaultdict

# %%
# 设置文件夹路径
question_dir = 'D:\\VQA\\validation\\Questions'
answers_dir = 'D:\\VQA\\validation\\Answers'

# %%
def count_questions(directory):
    question_counts = defaultdict(int)
    error_files = []  # 用来收集出现解码错误的文件列表
    
    # 检查目录是否存在
    if not os.path.exists(directory):
        print(f"Directory does not exist: {directory}")
        return question_counts, error_files
    
    # 遍历指定目录下的所有文件
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)
        # 确保是文件而非目录
        if os.path.isfile(file_path):
            try:
                with open(file_path, 'r', encoding='utf-8') as file:
                    content = file.read().strip()  # 读取整个文件内容作为一个问题
                    question_counts[content] += 1
            except UnicodeDecodeError as e:
                # 添加到错误文件列表
                error_files.append((file_path, str(e)))

    return question_counts, error_files

# %%
# 调用函数并打印结果
results, errors = count_questions(question_dir)
if results:
    print("Question Counts:")
    for question, count in sorted(results.items(), key=lambda item: item[1], reverse=True):
        print(f"Question: '{question}' appears {count} times.")
else:
    print("No data found or directory is empty.")

if errors:
    print("\nError Files:")
    for file_path, error in errors:
        print(f"File '{file_path}' could not be read: {error}")
else:
    print("No decoding errors found.")
# Out:
# Question Counts:
# Question: 'How many cars are waiting to turn left in the bottom lane, moving from the bottom towards the left?' appears 6 times.
# Question: 'How many pedestrians are crossing the zebra crossing?' appears 5 times.
# Question: 'Are there many cars driving on the road right now? Not including the cars waiting at the traffic light.' appears 5 times.
# Question: 'How many people, including pedestrians, motorcyclists and cyclists  are waiting to cross the crosswalk from bottom left to bottom right' appears 3 times.
# Question: 'Did any car's that were waiting for a red light cross the white line?' appears 3 times.
# Question: 'In what direction is the car moving on the road? Excluding those that are waiting.' appears 3 times.
# Question: 'How many cars are going straight from left to right in the left lane?' appears 3 times.
# Question: 'How many cars are waiting to go stright in the left-hand lane, moving form the left to the right?' appears 3 times.
# Question: 'Are there many people and motorcycles on the crosswalk?' appears 3 times.
# Question: 'How many cars are traveling straight through the intersection?' appears 3 times.
# Question: 'How many vehicles are waiting to go straight in the lane beyond the intersection?' appears 2 times.
# Question: 'How many vehicles are waiting to turn left in the lane beyond the intersection?' appears 2 times.
# Question: 'How many motocyclists is waiting to go stright in the bottom lane.' appears 2 times.
# Question: 'How many cars are waiting to go stright in the bottom lane, moving from the bottom towards the top?' appears 2 times.
# Question: 'How many cars are going straight left to right?' appears 2 times.
# Question: 'Where are pedestrians crossing the road?' appears 2 times.
# Question: 'How many cars are driving from the top to the bottom?' appears 2 times.
# Question: 'How many cyclists are crossing the zebra crossing?' appears 2 times.
# Question: 'How many pedestrians cross the crosswalk from left to right' appears 2 times.
# Question: 'How many pedestrians are crossing the crosswalk from bottom left to top left' appears 2 times.
# Question: 'How many cars are turning left in the bottom lane, moving from the 	bottom towards the left?' appears 2 times.
# Question: 'Are there many pedestrians waiting to cross the street?' appears 2 times.
# Question: 'Is there a car going straight across the street?' appears 2 times.
# Question: 'How many vehicles are waiting to go straight in the bottom lane?' appears 2 times.
# Question: 'How many cars are waiting to go stright in the right-hand lane, moving form the right to the left?' appears 2 times.
# Question: 'Which way are the cars moving now?' appears 2 times.
# Question: 'What's in the left turn lane from the bottom to the left?' appears 2 times.
# Question: 'How many cars are waiting to turn left in  the lanes beyond the intersection, moving from the top towards the bottom?' appears 1 times.
# Question: 'How many pedestrians are crossing the crosswalk from right to left' appears 1 times.
# Question: 'How many people, including pedestrians, motorcyclists and cyclists  are waiting to cross the crosswalk from bottom left to upper left' appears 1 times.
# Question: 'How many cars are driving from the bottom to the top?' appears 1 times.
# Question: 'How many vehicles are going straight from right to left' appears 1 times.
# Question: 'Do you think there are many cars in the lane beyond the intersection?' appears 1 times.
# Question: 'What direction is the car in the bottom right of the image heading towards?' appears 1 times.
# Question: 'How many bicycles are crossing the zebra crossing?' appears 1 times.
# Question: 'Where is there a pedestrian crossing the street?' appears 1 times.
# Question: 'Where are the motorcyclists crossing the road?' appears 1 times.
# Question: 'Are there any vehicles turning left on the road?' appears 1 times.
# Question: 'How many pedestrians are waiting to cross the zebra crossing From bottom left to top left' appears 1 times.
# Question: 'How many taxis are in the picture?' appears 1 times.
# Question: 'How many pedestrians cross the crosswalk from right to left' appears 1 times.
# Question: 'Did any of the cars have their front wheels over the white line?' appears 1 times.
# Question: 'How many taxis are there in total?' appears 1 times.
# Question: 'How many cars are going straight in the right-hand lane, moving from the right to the left?' appears 1 times.
# Question: 'How many vehicles are waiting to turn left in the opposing lane, moving from the top towards the bottom?' appears 1 times.
# Question: 'Do you think there are many cars in the opposite lane?' appears 1 times.
# Question: 'Are there any motorcycles crossing the street?' appears 1 times.
# Question: 'Is there a bus on the road?' appears 1 times.
# Question: 'How many people are on the left waiting to go straight to the right?' appears 1 times.
# Question: 'How many cars are turning left from the right-hand lane to the bottom lane?' appears 1 times.
# Question: 'How many cars are turning left from the left-hand lane to the upper lane?' appears 1 times.
# Question: 'How many people are waiting to cross the crosswalk from bottom left to bottom right' appears 1 times.
# Question: 'How many people on motorcycles are in the left bottom of the picture?' appears 1 times.
# Question: 'How many motorcyclists are in the picture?' appears 1 times.
# Question: 'Where are pedestrians crossing the road' appears 1 times.
# Question: 'How many bicyclists and motorcyclists are waiting to cross the sidewalk from left to right in the lower left of the screen?' appears 1 times.
# Question: 'How many cars are turning left in the lanes beyond the intersection, moving from the lanes beyond the intersection towards the left?' appears 1 times.
# Question: 'How many cars are waiting to turn left in the left-hand lane, moving from the lane on the left towards the lane beyond the intersection?' appears 1 times.
# Question: 'What direction is the bus going?' appears 1 times.
# Question: 'Is there a car making a U-turn?' appears 1 times.
# Question: 'How many motocyclists are waiting to cross the zebra crossing from bottom left to bottom right' appears 1 times.
# Question: 'What's in the left turn lane from the top to the right?' appears 1 times.
# Question: 'Do you think there are many cars in lands beyond the intersection' appears 1 times.
# Question: 'What direction is the bus heading?' appears 1 times.
# Question: 'How many vehicles are making U-turns in the bottom lane?' appears 1 times.
# No decoding errors found.

# %%
def find_files_by_question(directory, target_question):
    matching_files = []
    
    # 检查目录是否存在
    if not os.path.exists(directory):
        print(f"Directory does not exist: {directory}")
        return matching_files
    
    # 遍历指定目录下的所有文件
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)
        # 确保是文件而非目录
        if os.path.isfile(file_path):
            try:
                with open(file_path, 'r', encoding='utf-8') as file:
                    content = file.read().strip()  # 读取整个文件内容
                    if content == target_question:  # 比较文件内容与目标问题
                        matching_files.append(filename)
            except UnicodeDecodeError:
                print(f"Could not decode file {file_path} using UTF-8.")

    return matching_files

# 用户输入的问题
target_question = ""

# 调用函数并打印结果
matching_files = find_files_by_question(question_dir, target_question)
if matching_files:
    print("Matching Files:")
    for file in matching_files:
        print(file)
else:
    print("No files match the provided question.")
# Out:
# Matching Files:
# 148709_sj8fas2e152d20211124air_420_1637216131_1637218737_143_obstacle.txt
# 148709_sj8fas2e152d20211124air_420_1637216131_1637218737_20_obstacle.txt
# 148709_sj8fas2e152d20211124air_420_1637216131_1637218737_213_obstacle.txt
# 148709_sj8fas2e152d20211124air_420_1637216131_1637218737_32_obstacle.txt
# 148709_sj8fas2e152d20211124air_420_1637216131_1637218737_84_obstacle.txt
# 148709_sj8fas2e152d20211124air_420_1637216131_1637218737_9_obstacle.txt

# %%
def find_and_replace_in_files(directory, target_question, new_content):
    matching_files = []
    modified_files = []

    # 检查目录是否存在
    if not os.path.exists(directory):
        print(f"Directory does not exist: {directory}")
        return matching_files, modified_files

    # 遍历指定目录下的所有文件
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)
        # 确保是文件而非目录
        if os.path.isfile(file_path):
            try:
                with open(file_path, 'r', encoding='utf-8') as file:
                    content = file.read().strip()  # 读取整个文件内容
                    if content == target_question:  # 比较文件内容与目标问题
                        matching_files.append(filename)

                        # 替换文件内容
                        with open(file_path, 'w', encoding='utf-8') as file_to_write:
                            file_to_write.write(new_content)
                            modified_files.append(filename)
            except UnicodeDecodeError:
                print(f"Could not decode file {file_path} using UTF-8.")
            except IOError as e:
                print(f"Error while writing to file {file_path}: {e}")

    return matching_files, modified_files


# 用户输入的问题和新内容
target_question = ""
new_content = ""

# 调用函数并打印结果
matching_files, modified_files = find_and_replace_in_files(question_dir, target_question, new_content)
if matching_files:
    print("Matching Files:")
    for file in matching_files:
        print(file)
    print("\nModified Files:")
    for file in modified_files:
        print(file)
else:
    print("No files match the provided question.")
# Out:
# No files match the provided question.
